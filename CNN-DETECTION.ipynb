# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import pandas as pd
import numpy as np

# %%
image = img_to_array(load_img("image2.jpg", color_mode="grayscale"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 image = img_to_array(load_img("image2.jpg", color_mode="grayscale"))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image2.jpg'

# %%
# image=plt.imread('image2.jpg')
plt.imshow(image)
plt.show()

# %%
type(image)
# Out:
# numpy.ndarray

# %%
fig,ax = plt.subplots(1,figsize=(10,10))

rec = patches.Rectangle((4,30),25,-25,edgecolor='b',facecolor='none')

ax.add_patch(rec)

plt.imshow(image)

plt.show()

# %%
print(rec)
# Out:
# Rectangle(xy=(4, 30), width=25, height=-25, angle=0)

# %%
imageRec = image[0:28,0:28]
# plt.imshow(imageRec)
# plt.show()
# type(imageRec)

# %%
model = load_model("model_CNN_Mnist.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
pred = np.argmax(model.predict(imageRec.reshape(1,28,28,1)))
pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 5

# %% [markdown]
# EXERCICE :
# Parcoure l'image et detecte les objets qui sont sur l'image
